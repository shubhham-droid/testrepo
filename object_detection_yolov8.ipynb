# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR =  '/content/gdrive/My Drive/object_detn_yolo/data'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 691.5/691.5 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import os

# %%
from ultralytics import YOLO

# %%
#Load a model
model = YOLO("yolov8n.yaml")

#using the model
results = model.train(data=os.path.join(ROOT_DIR,"data_config.yaml"),epochs=1)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# Your code for object detection using YOLO here
# !scp -r /content/runs/detect/train2 '/content/gdrive/My Drive/object_detn_yolo'

# %%
from PIL import Image, ImageDraw

# %%
# Path to your unseen image
image_path = '/content/gdrive/My Drive/object_detn_yolo/test_2.jpg'

# Perform object detection on the unseen image
results = model(image_path)

# Load the image using PIL
img = Image.open(image_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-995055cfcd82> in <cell line: 5>()
#       3
#       4 # Perform object detection on the unseen image
# ----> 5 results = model(image_path)
#       6
#       7 # Load the image using PIL
#
# NameError: name 'model' is not defined

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'boat', 1: 'car', 2: 'dock', 3: 'jetski', 4: 'lift'}
#  orig_img: array([[[105, 182, 178],
#          [ 72, 148, 144],
#          [ 43, 115, 109],
#          ...,
#          [ 22,  47,  51],
#          [105, 129, 135],
#          [166, 192, 198]],
#
#         [[106, 188, 183],
#          [ 88, 168, 163],
#          [ 60, 137, 130],
#          ...,
#          [  0,  15,  20],
#          [  0,  20,  26],
#          [ 39,  63,  69]],
#
#         [[ 90, 183, 176],
#          [ 87, 177, 171],
#          [ 80, 166, 160],
#          ...,
#          [ 48,  69,  71],
#          [ 31,  51,  56],
#          [ 24,  46,  51]],
#
#         ...,
#
#         [[110, 140, 141],
#          [108, 138, 139],
#          [106, 136, 137],
#          ...,
#          [103, 133, 134],
#          [103, 133, 134],
#          [104, 134, 135]],
#
# ...
